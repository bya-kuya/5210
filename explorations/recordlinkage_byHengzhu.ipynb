# %%
import pandas as pd
import recordlinkage
from recordlinkage.preprocessing import clean, phonetic

# %%
left_dataset_path = './data/left_dataset.csv'
right_dataset_path = './data/right_dataset.csv'
left = pd.read_csv(left_dataset_path)
right = pd.read_csv(right_dataset_path)

# %%
left
# Out:
#        entity_id                              name  \
# 0              1                     The UPS Store
# 1              2                St Honore Pastries
# 2              3          Perkiomen Valley Brewery
# 3              4                    Sonic Drive-In
# 4              5                   Famous Footwear
# ...          ...                               ...
# 94580      94581     Adelita Taqueria & Restaurant
# 94581      94582  INSPcenter/Thai Clinical Massage
# 94582      94583              Wild Birds Unlimited
# 94583      94584                 Claire's Boutique
# 94584      94585                           Sic Ink
#
#                                           address          city state  \
# 0                 87 Grasso Plaza Shopping Center        Affton    MO
# 1                                     935 Race St  Philadelphia    PA
# 2                                   101 Walnut St    Green Lane    PA
# 3                                   615 S Main St  Ashland City    TN
# 4      8522 Eager Road, Dierbergs Brentwood Point     Brentwood    MO
# ...                                           ...           ...   ...
# 94580                               1108 S 9th St  Philadelphia    PA
# 94581                 2625 N Meridian St, Unit 50  Indianapolis    IN
# 94582                          2813 Bransford Ave     Nashville    TN
# 94583                      6020 E 82nd St, Ste 46  Indianapolis    IN
# 94584                       238 Apollo Beach Blvd  Apollo beach    FL
#
#        postal_code                                         categories
# 0          63123.0  Shipping Centers, Local Services, Notaries, Ma...
# 1          19107.0  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 2          18054.0                          Brewpubs, Breweries, Food
# 3          37015.0  Burgers, Fast Food, Sandwiches, Food, Ice Crea...
# 4          63144.0  Sporting Goods, Fashion, Shoe Stores, Shopping...
# ...            ...                                                ...
# 94580      19147.0                               Restaurants, Mexican
# 94581      46208.0  Massage Therapy, Rolfing, Beauty & Spas, Refle...
# 94582      37204.0  Pets, Nurseries & Gardening, Pet Stores, Hobby...
# 94583      46250.0  Shopping, Jewelry, Piercing, Toy Stores, Beaut...
# 94584      33572.0  Beauty & Spas, Permanent Makeup, Piercing, Tattoo
#
# [94585 rows x 7 columns]

# %%
right
# Out:
#        business_id                                  name  \
# 0                1                 SOURINI PAINTING INC.
# 1                2                  WOLFF DOLLA BILL LLC
# 2                3     COMPREHENSIVE SURGERY CENTER, LLC
# 3                4              FRANK & ADAM APPAREL LLC
# 4                5             MORENO PLUS TRANSPORT INC
# ...            ...                                   ...
# 91786        91787                     DEH TRANSPORT LLC
# 91787        91788                           TM INC. LLC
# 91788        91789  PASSION TRANSPORTATION SERVICES, LLC
# 91789        91790     ROSIE CLEANING SERVICE/COMMERCIAL
# 91790        91791                     THE AQUADUCKS LLC
#
#                             address        city state    zip_code  size
# 0                   12800 44th St N  Clearwater    FL  33762-4726  11.0
# 1                   1905 E 19th Ave       Tampa    FL  33605-2700   8.0
# 2      1988 GULF TO BAY BLVD, Ste 1  CLEARWATER    FL  33765-3550   8.0
# 3                  13640 Wright Cir       Tampa    FL  33626-3030  12.0
# 4         8608 Huron Court unite 58       Tampa    FL       33614   8.0
# ...                             ...         ...   ...         ...   ...
# 91786               737 E Statue Ct    Franklin    TN  37067-5637   2.0
# 91787              4911 Georgia Ave   Nashville    TN  37209-2135   4.0
# 91788                 2005 QUAIL DR   NASHVILLE    TN       37207   2.0
# 91789                  705 N 9TH ST   NASHVILLE    TN  37206-3907   5.0
# 91790                128 Gordon Ter   Nashville    TN  37207-4534   4.0
#
# [91791 rows x 7 columns]

# %%
def preprocess_data(df):
    for column in df.columns:
        if df[column].dtype == 'object':
            df[column] = df[column].str.replace(r'[^a-zA-Z0-9]', '', regex=True).str.lower()
    return df

# %%
left = preprocess_data(left)
right = preprocess_data(right)

# %%
left
# Out:
#        entity_id                           name  \
# 0              1                    theupsstore
# 1              2               sthonorepastries
# 2              3         perkiomenvalleybrewery
# 3              4                   sonicdrivein
# 4              5                 famousfootwear
# ...          ...                            ...
# 94580      94581      adelitataqueriarestaurant
# 94581      94582  inspcenterthaiclinicalmassage
# 94582      94583             wildbirdsunlimited
# 94583      94584                clairesboutique
# 94584      94585                         sicink
#
#                                     address          city state  postal_code  \
# 0               87grassoplazashoppingcenter        affton    mo      63123.0
# 1                                 935racest  philadelphia    pa      19107.0
# 2                               101walnutst     greenlane    pa      18054.0
# 3                                615smainst   ashlandcity    tn      37015.0
# 4      8522eagerroaddierbergsbrentwoodpoint     brentwood    mo      63144.0
# ...                                     ...           ...   ...          ...
# 94580                            1108s9thst  philadelphia    pa      19147.0
# 94581                 2625nmeridianstunit50  indianapolis    in      46208.0
# 94582                      2813bransfordave     nashville    tn      37204.0
# 94583                      6020e82ndstste46  indianapolis    in      46250.0
# 94584                    238apollobeachblvd   apollobeach    fl      33572.0
#
#                                               categories
# 0      shippingcenterslocalservicesnotariesmailboxcen...
# 1              restaurantsfoodbubbleteacoffeeteabakeries
# 2                                  brewpubsbreweriesfood
# 3      burgersfastfoodsandwichesfoodicecreamfrozenyog...
# 4      sportinggoodsfashionshoestoresshoppingsportswe...
# ...                                                  ...
# 94580                                 restaurantsmexican
# 94581  massagetherapyrolfingbeautyspasreflexologyheal...
# 94582  petsnurseriesgardeningpetstoreshobbyshopsbirds...
# 94583  shoppingjewelrypiercingtoystoresbeautyspasacce...
# 94584            beautyspaspermanentmakeuppiercingtattoo
#
# [94585 rows x 7 columns]

# %%
right
# Out:
#        business_id                              name                address  \
# 0                1                sourinipaintinginc           1280044thstn
# 1                2                 wolffdollabillllc           1905e19thave
# 2                3     comprehensivesurgerycenterllc  1988gulftobayblvdste1
# 3                4               frankadamapparelllc         13640wrightcir
# 4                5            morenoplustransportinc  8608huroncourtunite58
# ...            ...                               ...                    ...
# 91786        91787                   dehtransportllc           737estatuect
# 91787        91788                          tmincllc         4911georgiaave
# 91788        91789  passiontransportationservicesllc            2005quaildr
# 91789        91790    rosiecleaningservicecommercial              705n9thst
# 91790        91791                   theaquaducksllc           128gordonter
#
#              city state   zip_code  size
# 0      clearwater    fl  337624726  11.0
# 1           tampa    fl  336052700   8.0
# 2      clearwater    fl  337653550   8.0
# 3           tampa    fl  336263030  12.0
# 4           tampa    fl      33614   8.0
# ...           ...   ...        ...   ...
# 91786    franklin    tn  370675637   2.0
# 91787   nashville    tn  372092135   4.0
# 91788   nashville    tn      37207   2.0
# 91789   nashville    tn  372063907   5.0
# 91790   nashville    tn  372074534   4.0
#
# [91791 rows x 7 columns]

# %%
print(left.columns.tolist())
# Out:
# ['entity_id', 'name', 'address', 'city', 'state', 'postal_code', 'categories']

# %%
print(right.columns.tolist())
# Out:
# ['business_id', 'name', 'address', 'city', 'state', 'zip_code', 'size']

# %%
left.rename(columns={'postal_code': 'zip_code'}, inplace=True)

# %%
left
# Out:
#        entity_id                           name  \
# 0              1                    theupsstore
# 1              2               sthonorepastries
# 2              3         perkiomenvalleybrewery
# 3              4                   sonicdrivein
# 4              5                 famousfootwear
# ...          ...                            ...
# 94580      94581      adelitataqueriarestaurant
# 94581      94582  inspcenterthaiclinicalmassage
# 94582      94583             wildbirdsunlimited
# 94583      94584                clairesboutique
# 94584      94585                         sicink
#
#                                     address          city state  zip_code  \
# 0               87grassoplazashoppingcenter        affton    mo   63123.0
# 1                                 935racest  philadelphia    pa   19107.0
# 2                               101walnutst     greenlane    pa   18054.0
# 3                                615smainst   ashlandcity    tn   37015.0
# 4      8522eagerroaddierbergsbrentwoodpoint     brentwood    mo   63144.0
# ...                                     ...           ...   ...       ...
# 94580                            1108s9thst  philadelphia    pa   19147.0
# 94581                 2625nmeridianstunit50  indianapolis    in   46208.0
# 94582                      2813bransfordave     nashville    tn   37204.0
# 94583                      6020e82ndstste46  indianapolis    in   46250.0
# 94584                    238apollobeachblvd   apollobeach    fl   33572.0
#
#                                               categories
# 0      shippingcenterslocalservicesnotariesmailboxcen...
# 1              restaurantsfoodbubbleteacoffeeteabakeries
# 2                                  brewpubsbreweriesfood
# 3      burgersfastfoodsandwichesfoodicecreamfrozenyog...
# 4      sportinggoodsfashionshoestoresshoppingsportswe...
# ...                                                  ...
# 94580                                 restaurantsmexican
# 94581  massagetherapyrolfingbeautyspasreflexologyheal...
# 94582  petsnurseriesgardeningpetstoreshobbyshopsbirds...
# 94583  shoppingjewelrypiercingtoystoresbeautyspasacce...
# 94584            beautyspaspermanentmakeuppiercingtattoo
#
# [94585 rows x 7 columns]

# %%
right
# Out:
#        business_id                              name                address  \
# 0                1                sourinipaintinginc           1280044thstn
# 1                2                 wolffdollabillllc           1905e19thave
# 2                3     comprehensivesurgerycenterllc  1988gulftobayblvdste1
# 3                4               frankadamapparelllc         13640wrightcir
# 4                5            morenoplustransportinc  8608huroncourtunite58
# ...            ...                               ...                    ...
# 91786        91787                   dehtransportllc           737estatuect
# 91787        91788                          tmincllc         4911georgiaave
# 91788        91789  passiontransportationservicesllc            2005quaildr
# 91789        91790    rosiecleaningservicecommercial              705n9thst
# 91790        91791                   theaquaducksllc           128gordonter
#
#              city state   zip_code  size
# 0      clearwater    fl  337624726  11.0
# 1           tampa    fl  336052700   8.0
# 2      clearwater    fl  337653550   8.0
# 3           tampa    fl  336263030  12.0
# 4           tampa    fl      33614   8.0
# ...           ...   ...        ...   ...
# 91786    franklin    tn  370675637   2.0
# 91787   nashville    tn  372092135   4.0
# 91788   nashville    tn      37207   2.0
# 91789   nashville    tn  372063907   5.0
# 91790   nashville    tn  372074534   4.0
#
# [91791 rows x 7 columns]

# %%
string_columns = ['address', 'city', 'state', 'zip_code']
for column in string_columns:
    left[column] = left[column].astype(str)
    right[column] = right[column].astype(str)

# %%
left['address'] = left['address'].str.cat(left[['city', 'state', 'zip_code']], sep=' ')
right['address'] = right['address'].str.cat(right[['city', 'state', 'zip_code']], sep=' ')

# %%
left
# Out:
#        entity_id                           name  \
# 0              1                    theupsstore
# 1              2               sthonorepastries
# 2              3         perkiomenvalleybrewery
# 3              4                   sonicdrivein
# 4              5                 famousfootwear
# ...          ...                            ...
# 94580      94581      adelitataqueriarestaurant
# 94581      94582  inspcenterthaiclinicalmassage
# 94582      94583             wildbirdsunlimited
# 94583      94584                clairesboutique
# 94584      94585                         sicink
#
#                                                  address          city state  \
# 0          87grassoplazashoppingcenter affton mo 63123.0        affton    mo
# 1                      935racest philadelphia pa 19107.0  philadelphia    pa
# 2                       101walnutst greenlane pa 18054.0     greenlane    pa
# 3                      615smainst ashlandcity tn 37015.0   ashlandcity    tn
# 4      8522eagerroaddierbergsbrentwoodpoint brentwood...     brentwood    mo
# ...                                                  ...           ...   ...
# 94580                 1108s9thst philadelphia pa 19147.0  philadelphia    pa
# 94581      2625nmeridianstunit50 indianapolis in 46208.0  indianapolis    in
# 94582              2813bransfordave nashville tn 37204.0     nashville    tn
# 94583           6020e82ndstste46 indianapolis in 46250.0  indianapolis    in
# 94584          238apollobeachblvd apollobeach fl 33572.0   apollobeach    fl
#
#       zip_code                                         categories
# 0      63123.0  shippingcenterslocalservicesnotariesmailboxcen...
# 1      19107.0          restaurantsfoodbubbleteacoffeeteabakeries
# 2      18054.0                              brewpubsbreweriesfood
# 3      37015.0  burgersfastfoodsandwichesfoodicecreamfrozenyog...
# 4      63144.0  sportinggoodsfashionshoestoresshoppingsportswe...
# ...        ...                                                ...
# 94580  19147.0                                 restaurantsmexican
# 94581  46208.0  massagetherapyrolfingbeautyspasreflexologyheal...
# 94582  37204.0  petsnurseriesgardeningpetstoreshobbyshopsbirds...
# 94583  46250.0  shoppingjewelrypiercingtoystoresbeautyspasacce...
# 94584  33572.0            beautyspaspermanentmakeuppiercingtattoo
#
# [94585 rows x 7 columns]

# %%
right
# Out:
#        business_id                              name  \
# 0                1                sourinipaintinginc
# 1                2                 wolffdollabillllc
# 2                3     comprehensivesurgerycenterllc
# 3                4               frankadamapparelllc
# 4                5            morenoplustransportinc
# ...            ...                               ...
# 91786        91787                   dehtransportllc
# 91787        91788                          tmincllc
# 91788        91789  passiontransportationservicesllc
# 91789        91790    rosiecleaningservicecommercial
# 91790        91791                   theaquaducksllc
#
#                                              address        city state  \
# 0               1280044thstn clearwater fl 337624726  clearwater    fl
# 1                    1905e19thave tampa fl 336052700       tampa    fl
# 2      1988gulftobayblvdste1 clearwater fl 337653550  clearwater    fl
# 3                  13640wrightcir tampa fl 336263030       tampa    fl
# 4               8608huroncourtunite58 tampa fl 33614       tampa    fl
# ...                                              ...         ...   ...
# 91786             737estatuect franklin tn 370675637    franklin    tn
# 91787          4911georgiaave nashville tn 372092135   nashville    tn
# 91788                 2005quaildr nashville tn 37207   nashville    tn
# 91789               705n9thst nashville tn 372063907   nashville    tn
# 91790            128gordonter nashville tn 372074534   nashville    tn
#
#         zip_code  size
# 0      337624726  11.0
# 1      336052700   8.0
# 2      337653550   8.0
# 3      336263030  12.0
# 4          33614   8.0
# ...          ...   ...
# 91786  370675637   2.0
# 91787  372092135   4.0
# 91788      37207   2.0
# 91789  372063907   5.0
# 91790  372074534   4.0
#
# [91791 rows x 7 columns]

# %%
columns_to_keep_left = ['entity_id', 'name', 'address']
columns_to_keep_right = ['business_id', 'name', 'address']
left_common = left[columns_to_keep_left]
right_common = right[columns_to_keep_right]

# %%
left_common
# Out:
#        entity_id                           name  \
# 0              1                    theupsstore
# 1              2               sthonorepastries
# 2              3         perkiomenvalleybrewery
# 3              4                   sonicdrivein
# 4              5                 famousfootwear
# ...          ...                            ...
# 94580      94581      adelitataqueriarestaurant
# 94581      94582  inspcenterthaiclinicalmassage
# 94582      94583             wildbirdsunlimited
# 94583      94584                clairesboutique
# 94584      94585                         sicink
#
#                                                  address
# 0          87grassoplazashoppingcenter affton mo 63123.0
# 1                      935racest philadelphia pa 19107.0
# 2                       101walnutst greenlane pa 18054.0
# 3                      615smainst ashlandcity tn 37015.0
# 4      8522eagerroaddierbergsbrentwoodpoint brentwood...
# ...                                                  ...
# 94580                 1108s9thst philadelphia pa 19147.0
# 94581      2625nmeridianstunit50 indianapolis in 46208.0
# 94582              2813bransfordave nashville tn 37204.0
# 94583           6020e82ndstste46 indianapolis in 46250.0
# 94584          238apollobeachblvd apollobeach fl 33572.0
#
# [94585 rows x 3 columns]

# %%
right_common
# Out:
#        business_id                              name  \
# 0                1                sourinipaintinginc
# 1                2                 wolffdollabillllc
# 2                3     comprehensivesurgerycenterllc
# 3                4               frankadamapparelllc
# 4                5            morenoplustransportinc
# ...            ...                               ...
# 91786        91787                   dehtransportllc
# 91787        91788                          tmincllc
# 91788        91789  passiontransportationservicesllc
# 91789        91790    rosiecleaningservicecommercial
# 91790        91791                   theaquaducksllc
#
#                                              address
# 0               1280044thstn clearwater fl 337624726
# 1                    1905e19thave tampa fl 336052700
# 2      1988gulftobayblvdste1 clearwater fl 337653550
# 3                  13640wrightcir tampa fl 336263030
# 4               8608huroncourtunite58 tampa fl 33614
# ...                                              ...
# 91786             737estatuect franklin tn 370675637
# 91787          4911georgiaave nashville tn 372092135
# 91788                 2005quaildr nashville tn 37207
# 91789               705n9thst nashville tn 372063907
# 91790            128gordonter nashville tn 372074534
#
# [91791 rows x 3 columns]

# %%
left_common['block_key'] = left_common['name'].str[:5]
right_common['block_key'] = right_common['name'].str[:5]
# Out:
# C:\Users\Johnz\AppData\Local\Temp\ipykernel_62240\1235932494.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   left_common['block_key'] = left_common['name'].str[:5]
# C:\Users\Johnz\AppData\Local\Temp\ipykernel_62240\1235932494.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   right_common['block_key'] = right_common['name'].str[:5]

# %%
indexer = recordlinkage.Index()
indexer.block('block_key')
candidate_links = indexer.index(left_common, right_common)

# %%
comparer = recordlinkage.Compare()
comparer.string('name', 'name', method='jarowinkler', label='name_similarity')
comparer.string('address', 'address', method='jarowinkler', label='address_similarity')

# %%
features = comparer.compute(candidate_links, left_common, right_common)

# %%
features['confidence_score'] = features.mean(axis=1)

# %%
threshold = 0.8
matches = features[features['confidence_score'] >= threshold]

# %%
matches
# Out:
#              name_similarity  address_similarity  confidence_score
# 7     81911         0.877419            0.747351          0.812385
#       82926         0.863158            0.928363          0.895760
#       84020         0.864865            0.921199          0.893032
# 3260  82926         0.863158            0.754873          0.809016
#       83734         0.888889            0.728115          0.808502
# ...                      ...                 ...               ...
# 94033 79875         1.000000            0.988235          0.994118
# 94034 72786         0.964706            0.970231          0.967469
# 94036 53965         0.925000            0.981602          0.953301
# 94167 69598         0.950000            0.970231          0.960116
# 94538 79362         0.925926            0.966950          0.946438
#
# [33298 rows x 3 columns]

# %%
matches['entity_id'] = matches.index.get_level_values(0)
matches['business_id'] = matches.index.get_level_values(1)
triplets = matches[['entity_id', 'business_id', 'confidence_score']].reset_index(drop=True)
triplets_list = [list(row) for row in triplets.values]
print(triplets_list)
# Out:
# [[7.0, 81911.0, 0.8123852124106793], [7.0, 82926.0, 0.8957602339181288], [7.0, 84020.0, 0.8930318476371109], [3260.0, 82926.0, 0.8090155945419104], [3260.0, 83734.0, 0.8085021694019996], [3260.0, 83848.0, 0.9171692745376956], [14768.0, 66427.0, 0.8370291693208359], [18149.0, 83954.0, 0.889871365423148], [18149.0, 84352.0, 0.9226278060743256], [27426.0, 82396.0, 0.9309582309582309], [27426.0, 82926.0, 0.8424564915792987], [27426.0, 83734.0, 0.8422737874350779], [34431.0, 83954.0, 0.8483571068036264], [34431.0, 84352.0, 0.823699930830661], [39881.0, 82926.0, 0.8042657289776165], [44101.0, 83954.0, 0.8069187956284731], [44101.0, 84352.0, 0.8012880931556654], [50104.0, 83954.0, 0.9017636926971864], [50104.0, 84020.0, 0.8008832002734443], [50104.0, 84352.0, 0.8458521401852388], [56401.0, 83848.0, 0.8370120120120121], [63579.0, 83954.0, 0.8380814175805686], [63579.0, 84352.0, 0.8078054938835924], [65096.0, 82396.0, 0.8327694527694528], [65096.0, 82926.0, 0.8211816409711147], [65096.0, 83734.0, 0.9383838383838384], [69705.0, 82396.0, 0.8292034281507965], [69705.0, 82926.0, 0.9263157894736842], [69705.0, 83734.0, 0.8374363327674024], [69705.0, 83848.0, 0.8068955298311016], [69705.0, 84020.0, 0.8375628350673723], [86820.0, 81911.0, 0.9212204999301774], [86820.0, 83734.0, 0.8080589505554443], [86820.0, 84020.0, 0.8217578292578291], [88703.0, 83954.0, 0.8041128084606346], [15718.0, 14318.0, 0.9118210342628947], [50413.0, 33337.0, 0.8398617511520737], [62920.0, 24014.0, 0.9733975701717636], [72770.0, 33337.0, 0.9068747381650608], [84246.0, 53654.0, 0.9209850606909431], [304.0, 61824.0, 0.802390180878553], [1519.0, 80187.0, 0.8025298754131707], [2909.0, 80187.0, 0.8311695138068136], [18331.0, 57591.0, 0.8015208962577385], [18331.0, 80187.0, 0.9286751619030525], [20151.0, 88551.0, 0.9448171385671387], [20151.0, 88773.0, 0.939177927927928], [33054.0, 57591.0, 0.8094152046783626], [33054.0, 61824.0, 0.8119838567728239], [33054.0, 80187.0, 0.8033028222730739], [36544.0, 11160.0, 0.8969134281278494], [36544.0, 11161.0, 0.8969134281278494], [39995.0, 15537.0, 0.8831011876075814], [41146.0, 61824.0, 0.8251765314195145], [41146.0, 80187.0, 0.8698508002776921], [41242.0, 61824.0, 0.8030452826206111], [62506.0, 61824.0, 0.8263235787989339], [90829.0, 57591.0, 0.8170739348370928], [90829.0, 61824.0, 0.8104315860711209], [90829.0, 80187.0, 0.8337528604118993], [25548.0, 43371.0, 0.8606295599309517], [27865.0, 86617.0, 0.8500156619265571], [34383.0, 43371.0, 0.8061282176604757], [64534.0, 72859.0, 0.8025252525252525], [86683.0, 76627.0, 0.8766338336460288], [10201.0, 60299.0, 0.9555065359477124], [47371.0, 52259.0, 0.9270065359477124], [47371.0, 55125.0, 0.949077964519141], [51475.0, 52259.0, 0.8178142358730595], [51475.0, 55125.0, 0.8099747420335656], [51475.0, 60299.0, 0.8787358747795181], [70714.0, 60299.0, 0.8362651727357611], [10.0, 28460.0, 0.8279313404313404], [10799.0, 5188.0, 0.9540435312881133], [20915.0, 28460.0, 0.831828852662186], [56357.0, 48322.0, 0.8202168903893042], [11795.0, 58424.0, 0.97005247005247], [11795.0, 58425.0, 0.9803088803088803], [25080.0, 39938.0, 0.8246537775949541], [25080.0, 41847.0, 0.9720588235294118], [31574.0, 60810.0, 0.9795945945945946], [35185.0, 80938.0, 0.8847041847041848], [59867.0, 81025.0, 0.9795945945945946], [59867.0, 81026.0, 0.9693381843381843], [60930.0, 10012.0, 0.9759013282732447], [77955.0, 60810.0, 0.8270739348370928], [2409.0, 53618.0, 0.9708624708624709], [2409.0, 57557.0, 0.9825108225108226], [9236.0, 44845.0, 0.9666911255146549], [10555.0, 44845.0, 0.8095128763756215], [59840.0, 59148.0, 0.9475], [3757.0, 79734.0, 0.8496816890782408], [18867.0, 79734.0, 0.9705065359477124], [56365.0, 9797.0, 0.950925925925926], [74721.0, 10013.0, 0.9558441558441558], [87310.0, 79734.0, 0.8154761904761905], [1133.0, 26499.0, 0.8037418866830632], [3117.0, 71228.0, 0.8290666059087112], [3117.0, 75972.0, 0.838631831131831], [3117.0, 76635.0, 0.8680401080401081], [6144.0, 19658.0, 0.9573136645962732], [11790.0, 5047 ...
# C:\Users\Johnz\AppData\Local\Temp\ipykernel_62240\2700086379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['entity_id'] = matches.index.get_level_values(0)
# C:\Users\Johnz\AppData\Local\Temp\ipykernel_62240\2700086379.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches['business_id'] = matches.index.get_level_values(1)

# %%
columns=columns = ['entity_id', 'business_id', 'confidence_score']
matched = pd.DataFrame(matches[['entity_id', 'business_id', 'confidence_score']], columns=columns)

# %%
print(matched)
# Out:
#              entity_id  business_id  confidence_score
# 7     81911          7        81911          0.812385
#       82926          7        82926          0.895760
#       84020          7        84020          0.893032
# 3260  82926       3260        82926          0.809016
#       83734       3260        83734          0.808502
# ...                ...          ...               ...
# 94033 79875      94033        79875          0.994118
# 94034 72786      94034        72786          0.967469
# 94036 53965      94036        53965          0.953301
# 94167 69598      94167        69598          0.960116
# 94538 79362      94538        79362          0.946438
#
# [33298 rows x 3 columns]

# %%
matched.rename(columns={'entity_id':'left_dataset','business_id':'right_dataset','confidence_score':'confidence_score'})
# Out:
#              left_dataset  right_dataset  confidence_score
# 7     81911             7          81911          0.812385
#       82926             7          82926          0.895760
#       84020             7          84020          0.893032
# 3260  82926          3260          82926          0.809016
#       83734          3260          83734          0.808502
# ...                   ...            ...               ...
# 94033 79875         94033          79875          0.994118
# 94034 72786         94034          72786          0.967469
# 94036 53965         94036          53965          0.953301
# 94167 69598         94167          69598          0.960116
# 94538 79362         94538          79362          0.946438
#
# [33298 rows x 3 columns]
